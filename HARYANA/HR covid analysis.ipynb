# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
from datetime import datetime
plt.rcParams['figure.figsize'] = [30,12]

# %%
def get_monthday(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[0]
    if date[1]=="02":
        return "February"+date[0]
    if date[1]=="03":
        return "March"+date[0]
    if date[1]=="04":
        return "April"+date[0]
    if date[1]=="05":
        return "May"+date[0]
    if date[1]=="06":
        return "June"+date[0]
    if date[1]=="07":
        return "July"+date[0]
    if date[1]=="08":
        return "August"+date[0]
    if date[1]=="09":
        return "September"+date[0]
    if date[1]=="10":
        return "October"+date[0]
    if date[1]=="11":
        return "November"+date[0]
    if date[1]=="12":
        return "December"+date[0]
def get_month(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[2]
    if date[1]=="02":
        return "February"+date[2]
    if date[1]=="03":
        return "March"+date[2]
    if date[1]=="04":
        return "April"+date[2]
    if date[1]=="05":
        return "May"+date[2]
    if date[1]=="06":
        return "June"+date[2]
    if date[1]=="07":
        return "July"+date[2]
    if date[1]=="08":
        return "August"+date[2]
    if date[1]=="09":
        return "September"+date[2]
    if date[1]=="10":
        return "October"+date[2]
    if date[1]=="11":
        return "November"+date[2]
    if date[1]=="12":
        return "December"+date[2]
    
def get_year(date):
    date=date.split("-")
    return date[0]
def Histogram(x,y,xlabel,ylabel,title):
    x.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["red"],rwidth=0.8
       )
    y.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["blue"],rwidth=0.8
       )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
def bar_graph(categories,cat_val,xlabel,ylabel,title="",color="blue"):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.bar(categories,cat_val,width=0.8,color=color)
    plt.title(title)
    plt.show()
# This is the code of linear_regression model also.........           
def linear_correlation(x,y):
    meanx=sum(x.values)/len(x)
    meany=sum(y.values)/len(y)
    if len(x.values)==len(y.values):
        num,den=0,0
        #numerator calculation
        a=0
        for i in range(len(x)):
            a+=x.values[i]*y.values[i]
            #         print(a)
        num=a*len(x)-(sum(x.values)*sum(y.values))
    
        #denominator calculation
        ax,ay=0,0
        for i in range(len(x)):
                ax+=x.values[i]**2
                ay+=y.values[i]**2 
        p1=(len(x)*ax-(sum(x.values)**2))**0.5
        p2=(len(y)*ay-(sum(y.values)**2))**0.5
        den=p1*p2
        #print(num,den)
        return num/den
    else:
        raise Exception("Invalid Dimension")
import datetime
import calendar
 
def get_day(date):
    day, month, year = (int(i) for i in date.split('-'))   
    dayNumber = calendar.weekday(year, month, day)
    days =["Monday", "Tuesday", "Wednesday", "Thursday",
                         "Friday", "Saturday", "Sunday"]
    return (days[dayNumber])

def set_index(x):
    if x=="June2020":
        return -2
    if x=="July2020":
        return -1
    if x=="August2020":
        return 0
    if x=="September2020":
        return 1
    if x=="October2020":
        return 2
    if x=="November2020":
        return 3
    if x=="December2020":
        return 4
    if x=="January2021":
        return 5
    if x=="February2021":
        return 6
    if x=="March2021":
        return 7
    if x=="April2021":
        return 8
    if x=="May2021":
        return 9
    if x=="June2021":
        return 10
    if x=="July2021":
        return 11
    if x=="August2021":
        return 12
    if x=="September2021":
        return 13
    if x=="October2021":
        return 14
    if x=="November2021":
        return 15
    if x=="December2021":
        return 16
    if x=="January2022":
        return 17
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    #     explode = (0,0.1)
    plt.pie(values,labels=values,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1
# vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
def plot_bar_graphs(data,values,xlabel="",ylabel="",title=""):
    data[values].plot(kind="bar",title="",xlabel=xlabel,ylabel=ylabel)
def variant(date):
    date = date.split('-')
    if date[0] == '2020':
        return 'alpha'
    elif date[0] == '2021':
        if (date[1] == '01' or date[1] == '02' or date[1] == '03'):
            return 'alpha'
        elif date[1] == '12':
            return 'omicron'
        else:
            return 'delta'
    elif date[0] == '2022':
        return 'omicron'
def TPR(total_tests,positive):
    return (positive/total_tests)*100
def comorb(s):
    if s=="no comorbidity":
        return "no comorbidity"
    else:
        return "comorbidity"
def cato(s):
    if "Government" in s or "Govt" in s or "govt" in s or "government" in s:
        return "Government facility"
    if "Private" in s :
        return "Private facility"
    if "college" in s:
        return "Medical college"
    else:
        return "Others"

# %%
HRcaseinfo=pd.read_csv("HR_case_info.csv")
HRcritical=pd.read_csv("HR_critical_case_info.csv")
HRdistrictinfo=pd.read_csv("HR_district_info.csv")

# %%
HRcaseinfo1=HRcaseinfo.copy()

# %%
HRcaseinfo1["month"]=HRcaseinfo["date"].copy()
HRcaseinfo1["year"]=HRcaseinfo["date"].copy()
HRcaseinfo1["month"]=HRcaseinfo1["month"].apply(lambda x:get_month(x))
HRcaseinfo1["year"]=HRcaseinfo1["year"].apply(lambda x:get_year(x))
HRcaseinfo1['rise in cases']= ""
HRcaseinfo1['rise in cases'] = HRcaseinfo1['cases_new'].diff()

# %%
HRcaseinfo1=HRcaseinfo1.groupby("month").agg("sum").reset_index()
HRcaseinfo1["index"]=HRcaseinfo1["month"].copy()
HRcaseinfo1["index"]=HRcaseinfo1["index"].apply(lambda x: set_index(x))
HRcaseinfo1.sort_values(by="index",inplace=True)
HRcaseinfo1
# Out:
#             month  samples_taken_today  samples_sent_cumulative  \
# 8        July2020                  0.0                      0.0
# 1      August2020                  0.0                      0.0
# 17  September2020                  0.0                      0.0
# 15    October2020                  0.0                      0.0
# 13   November2020             153441.0               17240005.0
# 3    December2020             927015.0              118204326.0
# 6     January2021             618174.0              152143248.0
# 5    February2021             497654.0              152411798.0
# 11      March2021             572633.0              178543848.0
# 0       April2021            1138264.0              203501259.0
# 12        May2021            1394446.0              214138972.0
# 10       June2021             827533.0              239616125.0
# 9        July2021             738465.0              294674112.0
# 2      August2021             810819.0              350227271.0
# ...

# %%
HRcase=HRdistrictinfo.groupby("date").sum().reset_index()
HRcase["positive_cases_today"]
# Out:
# 0       286
# 1      1104
# 2        92
# 3      1609
# 4      1233
#        ...
# 485    1450
# 486      20
# 487      11
# 488     271
# 489     854
# Name: positive_cases_today, Length: 490, dtype: int64

# %% [markdown]
# ## Graph1
# **The below graph plots no of new cases per day from July2020 to January2021**

# %% [markdown]
# PROPERTIES OF GRAPH:
# Blue curve:
# 1) If the curve is going up --> means number of cases per day are increasing
# 2) If the curve is going down --> means the number of cases per day are decreasing
# 3) If the curve is flat --> means there is no change in the number cases per day
#
#   Orange curve:
# 1) If the curve is going up --> means number of recovered cases per day is increasing
# 2) If the curve is going down --> means the number of recovered cases per day is decreasing
# 3) If the curve is flat --> means there is no change in the number recovered cases per day

# %%
plt.ticklabel_format(style='plain')
plt.plot(HRcaseinfo["date"],HRcaseinfo["active_cases"])

# %%
HRcase["month"]=HRcase["date"].copy()
HRcase["year"]=HRcase["date"].copy()
HRcase["month"]=HRcase["month"].apply(lambda x:get_month(x))
HRcase["year"]=HRcase["year"].apply(lambda x:get_year(x))
HRcase['rise in cases']= ""
HRcase['rise in cases'] = HRcaseinfo['cases_new'].diff()
HRcase
# Out:
#            date  positive_cases_today  positive_cases_cumulative  \
# 0    01-01-2021                   286                     262611
# 1    01-01-2022                  1104                    1548680
# 2    01-02-2021                    92                     267989
# 3    01-04-2021                  1609                     292409
# 4    01-06-2021                  1233                     757868
# ..          ...                   ...                        ...
# 485  31-08-2020                  1450                      64732
# 486  31-08-2021                    20                     770486
# 487  31-10-2021                    11                     771252
# 488  31-12-2020                   271                     262325
# 489  31-12-2021                   854                    1547576
#
#      recovered_total  recovered_new  recovery_rate  deaths_with_comorbidity  \
# 0             256386          533.0        2139.75                   2548.0
# ...

# %%
HRcase=HRcase.groupby("month").agg("sum").reset_index()
HRcase["index"]=HRcase["month"].copy()
HRcase["index"]=HRcase["index"].apply(lambda x: set_index(x))
HRcase.sort_values(by="index",inplace=True)
HRcase
# Out:
#             month  positive_cases_today  positive_cases_cumulative  \
# 8        July2020                 11554                     464237
# 1      August2020                 29767                    1498908
# 17  September2020                 62178                    2844774
# 15    October2020                 36868                    4418890
# 13   November2020                 66916                    6040289
# 3    December2020                 26704                    7060792
# 6     January2021                  5419                    7972394
# 5    February2021                  1584                    4569568
# 11      March2021                 10913                    4459383
# 0       April2021                189876                   10122279
# 12        May2021                220972                   16692253
# 10       June2021                 10525                   19131574
# 9        July2021                  1077                   21545075
# ...

# %% [markdown]
# ## Graph2
# **The below bar graph plots no. of positive cases per each month.**

# %%
bar_graph(HRcase["month"],HRcase["positive_cases_today"],"month","no of cases","no of cases in each month")

# %% [markdown]
# ## Graph3
# **The below bar graph plots no. of recovered cases per each month.**

# %%
bar_graph(HRcase["month"],HRcase["recovered_new"],"month","no of recovered cases","no of recovered cases in each month","red")

# %% [markdown]
# **Description: From Graph3 we can observe that the no. of recovered cases are high in april and may 2021.**

# %% [markdown]
# ## Graph4
# **The below bar graph plots no. of first doses per each month (from March2021 to Jan2022).**

# %%
bar_graph(HRcaseinfo1["month"][list(HRcaseinfo1["month"]).index("March2021"):],HRcaseinfo1["vax_today_first_dose"][list(HRcaseinfo1["month"]).index("March2021"):],"month","no of doses","sd","green")

# %% [markdown]
# ## Graph5
# **The below bar graph plots no. of second doses per each month (from March2021 to Jan2022).**

# %%
plt.ticklabel_format(style='plain')
bar_graph(HRcaseinfo1["month"][list(HRcaseinfo1["month"]).index("March2021"):],HRcaseinfo1["vax_today_second_dose"][list(HRcaseinfo1["month"]).index("March2021"):],"month","no of doses","sd","brown")

# %% [markdown]
# ## Graph6
# **The below graph plots no. of First doses vs no. of second doses per day from March2021 to January2022**

# %% [markdown]
# PROPERTIES OF GRAPH6:
# Blue curve:
# 1) If the curve is going up --> means number of First doses given per day are increasing
# 2) If the curve is going down --> means the number of First doses given per day are decreasing
# 3) If the curve is flat --> means there is no change in the number First doses given per day
#
#   Orange curve:
# 1) If the curve is going up --> means number of second doses given per day is increasing
# 2) If the curve is going down --> means the number of second doses given per day is decreasing
# 3) If the curve is flat --> means there is no change in the number second doses given per day

# %%
plt.ticklabel_format(style='plain')
plt.plot(HRcaseinfo["date"],HRcaseinfo["vax_today_first_dose"])
plt.plot(HRcaseinfo["date"],HRcaseinfo["vax_today_second_dose"])
plt.legend(["First dose","Second dose"])

# %% [markdown]
# #### Mean 1st and 2nd doses gives per month:

# %%
x=HRcaseinfo1["vax_today_first_dose"][list(HRcaseinfo1["vax_today_first_dose"]).index(654976.0):].mean()
y=HRcaseinfo1["vax_today_second_dose"][list(HRcaseinfo1["vax_today_first_dose"]).index(654976.0):].mean()
print("\n",x ," is the mean no of 1st doses given per month\n",y," is the mean no of 2nd doses given per month")
# Out:
#  1719710.7272727273  is the mean no of 1st doses given per month
#  1328711.3636363635  is the mean no of 2nd doses given per month

# %% [markdown]
# ## Graph7
# **The below piechart plots deaths with comorbidities vs without comorbidities**

# %%
HRcasecom=HRcase.sum().reset_index()
piechart(["deaths with comorbidity","deaths without comorbidity"],[HRcasecom[0][6],HRcasecom[0][7]],)

# %% [markdown]
# **Description: From Graph7, we can say that the deaths in people with comorbidities is way to high compared to deaths in people without comorbidities.**

# %% [markdown]
# # Conculusions:
# From **Graph1 and Graph2** we can observe that there is a huge surge in cases during April2021 and May2021. There can be mutliple reasons to but one major reason can be poor vaccination drives which can be seen in **Graph6** From the analysis and calculations above the **mean no. people that got 1st dose per month are 1719710** and **no. of people that got 2nd dose are 1328711**. The surge in covid cases can be seen in April 2021 and May 2021. Vaccinations started around January 2021, Therefore by April aproximately **51,59,132 no. of people got 1st doses** and **39,86,133 no. of people got fully vacinated**. The total population of Haryana is 25,351,462 (source: https://haryana.gov.in/demography/) i.e only **20% got their 1st dose and 15% got fully vaccinated**.
# From **Graph7** we can observe that no. of deaths in cases with comorbidity are very high compared to no. of deaths in cases without comorbidity.
