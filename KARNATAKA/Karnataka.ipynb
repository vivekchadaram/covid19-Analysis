# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

from datetime import datetime
plt.rcParams['figure.figsize'] = [30,12]

# %%
def get_month(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[0]
    if date[1]=="02":
        return "February"+date[0]
    if date[1]=="03":
        return "March"+date[0]
    if date[1]=="04":
        return "April"+date[0]
    if date[1]=="05":
        return "May"+date[0]
    if date[1]=="06":
        return "June"+date[0]
    if date[1]=="07":
        return "July"+date[0]
    if date[1]=="08":
        return "August"+date[0]
    if date[1]=="09":
        return "September"+date[0]
    if date[1]=="10":
        return "October"+date[0]
    if date[1]=="11":
        return "November"+date[0]
    if date[1]=="12":
        return "December"+date[0]
    
    
def get_year(date):
    date=date.split("-")
    return date[0]
def Histogram(x,y,xlabel,ylabel,title):
    x.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["red"],rwidth=0.8
       )
    y.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["blue"],rwidth=0.8
       )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
def bar_graph(categories,cat_val,xlabel,ylabel,title=""):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.bar(categories,cat_val,width=0.8)
    plt.title(title)
    plt.show()
# This is the code of linear_regression model also.........           
def linear_correlation(x,y):
    meanx=sum(x.values)/len(x)
    meany=sum(y.values)/len(y)
    if len(x.values)==len(y.values):
        num,den=0,0
        #numerator calculation
        a=0
        for i in range(len(x)):
            a+=x.values[i]*y.values[i]
            #         print(a)
        num=a*len(x)-(sum(x.values)*sum(y.values))
    
        #denominator calculation
        ax,ay=0,0
        for i in range(len(x)):
                ax+=x.values[i]**2
                ay+=y.values[i]**2 
        p1=(len(x)*ax-(sum(x.values)**2))**0.5
        p2=(len(y)*ay-(sum(y.values)**2))**0.5
        den=p1*p2
        #print(num,den)
        return num/den
    else:
        raise Exception("Invalid Dimension")
import datetime
import calendar
 
def get_day(date):
    day, month, year = (int(i) for i in date.split('-'))   
    dayNumber = calendar.weekday(year, month, day)
    days =["Monday", "Tuesday", "Wednesday", "Thursday",
                         "Friday", "Saturday", "Sunday"]
    return (days[dayNumber])

def set_index(x):
    if x=="June2020":
        return -2
    if x=="July2020":
        return -1
    if x=="August2020":
        return 0
    if x=="September2020":
        return 1
    if x=="October2020":
        return 2
    if x=="November2020":
        return 3
    if x=="December2020":
        return 4
    if x=="January2021":
        return 5
    if x=="February2021":
        return 6
    if x=="March2021":
        return 7
    if x=="April2021":
        return 8
    if x=="May2021":
        return 9
    if x=="June2021":
        return 10
    if x=="July2021":
        return 11
    if x=="August2021":
        return 12
    if x=="September2021":
        return 13
    if x=="October2021":
        return 14
    if x=="November2021":
        return 15
    if x=="December2021":
        return 16
    if x=="January2022":
        return 17
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    #     explode = (0,0.1)
    plt.pie(values,labels=values,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1
# vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
def plot_bar_graphs(data,values,xlabel="",ylabel="",title=""):
    data[values].plot(kind="bar",title="",xlabel=xlabel,ylabel=ylabel)
def waves(date):
    date = date.split('-')
    if date[0] == '2020':
        return 'first'
    elif date[0] == '2021':
        if (date[1] == '01' or date[1] == '02' or date[1] == '03'):
            return 'first'
        else:
            return 'second'
    elif date[0] == '2022':
        return 'third'
def ages(age):
    if age < 18:
        return "children"
    elif age>18 and age<45:
        return "middle_age"
    else:
        return "old_age"
def comor(x):
    if x == '-':
        return "No_comorbidities"
    else:
        return "comorbidities"

# %% [markdown]
# # PART-1: VARIANTS,COVID-WAVES AND ITS POTENTIAL CAUSES:

# %%
district_cases = pd.read_csv("KA_district_cases.csv")
# district_cases

# %%
ka_cases = pd.read_csv("KA_case_info.csv")
ka_cases["month"]=ka_cases["date"].copy()
ka_cases["year"]=ka_cases["date"].copy()
ka_cases["month"]=ka_cases["month"].apply(lambda x:get_month(x))
ka_cases["year"]=ka_cases["year"].apply(lambda x:get_year(x))
ka_cases_mean=ka_cases.groupby(["month"]).mean()

# %%
ka_cases_mean["Index"]=ka_cases_mean.index.values.copy()
ka_cases_mean["Index"]=ka_cases_mean["Index"].apply(lambda x:set_index(x))
ka_cases_mean.sort_values(["Index"],inplace=True)
ka_cases_mean.drop(columns=['Index'],inplace=True)
# ka_cases_mean

# %% [markdown]
# **Graph1 below**.
#
# DESCRIPTION: The graph below is showing **positivity rate percent** in KARNATAKA

# %%
plt.plot(ka_cases_mean.index.values,ka_cases_mean["positivity_rate_percent"].values,color='red', marker='o', linestyle='-')

# %% [markdown]
# **Graph2 below**.
#
# DESCRIPTION: The graph below is showing **fatality rate percent** in KARNATAKA

# %%
plt.plot(ka_cases_mean.index.values,ka_cases_mean["fatality_rate_percent"].values,color='red', marker='o', linestyle='-')

# %% [markdown]
# **Graph3 below**.
#
# DESCRIPTION: The graph below is showing **critical cases rate** in KARNATAKA

# %%
plt.plot(ka_cases_mean.index.values,ka_cases_mean["active_cases_icu"].values,color='red', marker='o', linestyle='-')

# %%
district_cases.sort_values(by='date',ascending=False,inplace=True)
district_cases_la = district_cases.head(31)
district_cases_last_mean = district_cases_la.groupby('district').mean()
# district_cases_last_mean

# %%
district_cases_last_mean['avg_active_vs_total'] = ""
district_cases_last_mean['avg_active_vs_total'] = (district_cases_last_mean['active_cases_total']/district_cases_last_mean['cases_total'])*100
district_cases_last_mean['avg_recovered_vs_total'] = ""
district_cases_last_mean['avg_recovered_vs_total'] = (district_cases_last_mean['discharged_total']/district_cases_last_mean['cases_total'])*100
district_cases_last_mean['avg_deaths_vs_total'] = ""
district_cases_last_mean['avg_deaths_vs_total'] = (district_cases_last_mean['deaths_total']/district_cases_last_mean['cases_total'])*100
district_cases_last_mean
# Out:
#                   cases_new  cases_total  discharged_new  discharged_total  \
# district
# bagalakote              6.0      35195.0             0.0           34854.0
# ballari                34.0      97923.0             0.0           96061.0
# belagavi               31.0      80256.0             8.0           79129.0
# bengaluru rural        19.0      62212.0             4.0           61244.0
# bengaluru urban      3605.0    1272050.0           264.0         1240874.0
# bidar                   3.0      24360.0             0.0           23944.0
# chamarajanagara         2.0      33128.0             2.0           32603.0
# chikkaballapura         8.0      44024.0             1.0           43571.0
# chikkamagaluru         12.0      51490.0             5.0           51045.0
# chitradurga             6.0      36793.0             2.0           36555.0
# dakshina kannada      111.0     116731.0            11.0          114587.0
# ...

# %% [markdown]
# **Graph4 below**.
#
# DESCRIPTION: The graph below is showing **Average No of Active cases per total cases** in each district

# %%
bar_graph(district_cases_last_mean.index.values,district_cases_last_mean['avg_active_vs_total'].values,"Districts","Average Number of active cases","Average number of active cases per total cases in each district")
# plt.plot(alpha_district_cases_mean.index.values,alpha_district_cases_mean["avg_active_vs_total"].values,color='red', marker='o', linestyle='-')

# %% [markdown]
# **Graph5 below**.
#
# DESCRIPTION: The graph below is showing **Death rate per total cases** in each district

# %%
bar_graph(district_cases_last_mean.index.values,district_cases_last_mean['avg_deaths_vs_total'].values,"Districts","death rate","death rate per total cases in each district")

# %%
fatalities = pd.read_csv('KA_individual_fatalities.csv')
# fatalities

# %%
fatalities['age_group'] = fatalities['age'].copy()
fatalities['age_group'] = fatalities['age_group'].apply(lambda x:ages(x))
# fatalities.drop(columns=['notes'],inplace=True)
# fatalities

# %%
fatalities['bins'] = pd.cut(fatalities['age'],bins=[0,17,44,120], labels=["Age 0-17","Age 18-44","Age 45+"])
fatalities_bins = fatalities.groupby('bins').size().reset_index()
# fatalities_bins

# %% [markdown]
# **Graph6 below**.
#
# DESCRIPTION: The graph below is showing **No of Fatalities classified by age groups**.

# %%
# piec
# fatalities_bins.plot.pie(subplots=True,title="Number of fatalities in different age groups")
# plt.axes().set_ylabel('Age Groups')
piechart(fatalities_bins['bins'],fatalities_bins[0],'Number of fatalities in different age groups')

# %%
fatalities_gender = fatalities.groupby('sex').size().reset_index()
# fatalities_gender.plot.pie(subplots=True,title="Number of fatalities based on Gender")
# plt.axes().set_ylabel('')

# %%
fatalities_I = fatalities.groupby('description',dropna=True).count().reset_index()
# fatalities_I
# fatalities_ILI = fatalities_dummy.get_group('ILI')
# fatalities_ILI['comorbidities'].unique()

# %% [markdown]
# **Graph7 below**.
#
# DESCRIPTION: The graph below is showing **No of Fatalities who had various types of infections**.

# %%
fatalities_ILI=[fatalities_I['description'][10],fatalities_I['description'][11],fatalities_I['description'][14]]
fatalities_values=[fatalities_I['date'][10],fatalities_I['date'][11],fatalities_I['date'][14]]
piechart(fatalities_ILI,fatalities_values,'fatalities due to various Infections ')

# %%
fatalities_hosp = fatalities.groupby('place_of_death',dropna=True).count().reset_index()
# fatalities_hosp

# %%
fatalities_hospital =[fatalities_hosp['place_of_death'][5],fatalities_hosp['place_of_death'][9]]
fatalities_hosp_values=[fatalities_hosp['date'][5],fatalities_hosp['date'][9]]

# %% [markdown]
# **Graph8 below**.
#
# DESCRIPTION: The graph below is showing **fatalities in Desiginated hospitals & Private Hospitals**.

# %%
piechart(fatalities_hospital,fatalities_hosp_values,'fatalities in various hospitals ')

# %%
fatalities["comorbidities_found"]=fatalities.comorbidities.values.copy()
fatalities["comorbidities_found"]=fatalities["comorbidities_found"].apply(lambda x: comor(x))

# %%
fatalities_comoridities = fatalities.groupby('comorbidities_found',dropna=True).count().reset_index()
# fatalities_comoridities

# %%
fatalities_comor =[fatalities_comoridities['comorbidities_found'][0],fatalities_comoridities['comorbidities_found'][1]]
fatalities_comor_values=[fatalities_comoridities['date'][0],fatalities_comoridities['date'][1]]

# %% [markdown]
# **Graph9 below**.
#
# DESCRIPTION: The graph below is showing **Fatalities with comorbidities V/S Fatalities without comorbidities**.

# %%
piechart(fatalities_comor,fatalities_comor_values,"Fatalities with comorbidities V/S Fatalities without comorbidities")
