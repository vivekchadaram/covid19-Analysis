# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
from datetime import datetime
plt.rcParams['figure.figsize'] = [25,15]

# %%
def get_month(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[0]
    if date[1]=="02":
        return "February"+date[0]
    if date[1]=="03":
        return "March"+date[0]
    if date[1]=="04":
        return "April"+date[0]
    if date[1]=="05":
        return "May"+date[0]
    if date[1]=="06":
        return "June"+date[0]
    if date[1]=="07":
        return "July"+date[0]
    if date[1]=="08":
        return "August"+date[0]
    if date[1]=="09":
        return "September"+date[0]
    if date[1]=="10":
        return "October"+date[0]
    if date[1]=="11":
        return "November"+date[0]
    if date[1]=="12":
        return "December"+date[0]
    
    
def get_year(date):
    date=date.split("-")
    return date[0]
def Histogram(x,y,xlabel,ylabel,title):
    x.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["red"],rwidth=0.8
       )
    y.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["blue"],rwidth=0.8
       )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
def bar_graph(categories,cat_val,xlabel,ylabel,title=""):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.bar(categories,cat_val,width=0.8)
    plt.title(title)
    plt.show()
# This is the code of linear_regression model also.........           
def linear_correlation(x,y):
    meanx=sum(x.values)/len(x)
    meany=sum(y.values)/len(y)
    if len(x.values)==len(y.values):
        num,den=0,0
        #numerator calculation
        a=0
        for i in range(len(x)):
            a+=x.values[i]*y.values[i]
            #         print(a)
        num=a*len(x)-(sum(x.values)*sum(y.values))
    
        #denominator calculation
        ax,ay=0,0
        for i in range(len(x)):
                ax+=x.values[i]**2
                ay+=y.values[i]**2 
        p1=(len(x)*ax-(sum(x.values)**2))**0.5
        p2=(len(y)*ay-(sum(y.values)**2))**0.5
        den=p1*p2
        #print(num,den)
        return num/den
    else:
        raise Exception("Invalid Dimension")
import datetime
import calendar
 
def get_day(date):
    day, month, year = (int(i) for i in date.split('-'))   
    dayNumber = calendar.weekday(year, month, day)
    days =["Monday", "Tuesday", "Wednesday", "Thursday",
                         "Friday", "Saturday", "Sunday"]
    return (days[dayNumber])

def set_index(x):
    if x=="June2020":
        return -2
    if x=="July2020":
        return -1
    if x=="August2020":
        return 0
    if x=="September2020":
        return 1
    if x=="October2020":
        return 2
    if x=="November2020":
        return 3
    if x=="December2020":
        return 4
    if x=="January2021":
        return 5
    if x=="February2021":
        return 6
    if x=="March2021":
        return 7
    if x=="April2021":
        return 8
    if x=="May2021":
        return 9
    if x=="June2021":
        return 10
    if x=="July2021":
        return 11
    if x=="August2021":
        return 12
    if x=="September2021":
        return 13
    if x=="October2021":
        return 14
    if x=="November2021":
        return 15
    if x=="December2021":
        return 16
    if x=="January2022":
        return 17
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    #     explode = (0,0.1)
    plt.pie(values,labels=values,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1
# vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
def plot_bar_graphs(data,values,xlabel="",ylabel="",title=""):
    data[values].plot(kind="bar",title="",xlabel=xlabel,ylabel=ylabel)
def waves(date):
    date = date.split('-')
    if date[0] == '2020':
        return 'first'
    elif date[0] == '2021':
        if (date[1] == '01' or date[1] == '02' or date[1] == '03'):
            return 'first'
        else:
            return 'second'
    elif date[0] == '2022':
        return 'third'

# %% [markdown]
# # PART-1: VARIANTS,COVID-WAVES AND ITS POTENTIAL CAUSES:

# %%
uk_cases = pd.read_csv('UK_case_info.csv')
uk_cases.dropna(subset=['cases_new'],inplace = True)
uk_cases.reset_index(inplace=True)
uk_cases.drop(columns=['index'],inplace=True)
# uk_cases

# %%
uk_cases['rise in cases']= ""
uk_cases['rise in cases'] = uk_cases['active_cases'].diff()
uk_cases.dropna(subset=['rise in cases'],inplace=True)
uk_cases["month"]=uk_cases["date"].copy()
uk_cases["year"]=uk_cases["date"].copy()
uk_cases["month"]=uk_cases["month"].apply(lambda x:get_month(x))
uk_cases["year"]=uk_cases["year"].apply(lambda x:get_year(x))
# uk_cases

# %%
uk_cases_mean=uk_cases.groupby(["month"]).mean()
uk_cases_mean["Index"]=uk_cases_mean.index.values.copy()
uk_cases_mean["Index"]=uk_cases_mean["Index"].apply(lambda x:set_index(x))
uk_cases_mean.sort_values(["Index"],inplace=True)
uk_cases_mean.drop(columns=['Index'],inplace=True)
# uk_cases_mean

# %% [markdown]
# **Graph1 below.**
#
# DESCRIPTION:The graphw below are showing **number of positve cases** per month
#
# **Ogive curve

# %%
# bar_graph(uk_cases_mean.index.values,uk_cases_mean["cases_new"],"Months","Number of postive cases","Average positive cases (monthly data)")
plt.plot(uk_cases_mean.index.values,uk_cases_mean["cases_new"].values,color='red', marker='o', linestyle='-')

# %%
avg_positive_uk_cases = pd.DataFrame()
avg_positive_uk_cases['avg_positive_uk_cases'] = ""
avg_positive_uk_cases['avg_positive_uk_cases'] = (uk_cases_mean['cases_new']/uk_cases_mean['tests_today'])*100
# avg_positive_uk_cases

# %% [markdown]
# **Graph2 below**.
#
# DESCRIPTION:The graph below are showing average **number of positve cases** per month

# %%
bar_graph(avg_positive_uk_cases.index.values,avg_positive_uk_cases['avg_positive_uk_cases'].values,"Months","Number of postive cases per test cases","percentage of Average number of postive cases per test cases")

# %%
uk_cases_mean['deaths_today'] = ""
uk_cases_mean['deaths_today'] = uk_cases_mean['deaths_total'].diff()
uk_cases_mean['deaths_today'][0] = uk_cases_mean['deaths_total'][0]
# uk_cases_mean

# %% [markdown]
# **Graph3 below**.
#
# DESCRIPTION:The graph below are showing average **number of deaths** per month

# %%
# bar_graph(uk_cases_mean.index.values,uk_cases_mean['deaths_today'].values,"Months","Average Number of deaths","Average number of deaths month")
plt.plot(uk_cases_mean.index.values,uk_cases_mean["deaths_today"].values,color='red', marker='o', linestyle='-')

# %%
district_cases = pd.read_csv("UK_district_cases.csv")
district_cases["month"]=district_cases["date"].copy()
district_cases["year"]=district_cases["date"].copy()
district_cases["month"]=district_cases["month"].apply(lambda x:get_month(x))
district_cases["year"]=district_cases["year"].apply(lambda x:get_year(x))
index_names = district_cases[ district_cases['district_name']== 'Total'].index
district_cases.drop(index_names, inplace = True)
district_cases.reset_index(inplace=True)
district_cases.drop(columns=['index'],inplace=True)
# district_cases

# %%
wave = []
for i in district_cases['date']:
    wave.append(waves(i))
district_cases.insert(9,"waves",wave,True)
# district_cases

# %% [markdown]
# **First Wave and it's potential causes :**

# %%
district_cases_dummy= district_cases.groupby('waves')
first_district_cases = district_cases_dummy.get_group('first')
first_district_cases.sort_values(by='date',ascending=False,inplace=True)
first_district_cases = first_district_cases.head(13).copy()
# first_district_cases
# Out:
# <ipython-input-13-adb2e86dafb4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_district_cases.sort_values(by='date',ascending=False,inplace=True)

# %%
# here cases_total and Deaths total are cases_today and deaths_today respectively
first_district_cases_mean= first_district_cases.groupby('district_name',dropna=True).mean()
first_district_cases_mean['avg_active_vs_total'] = ""
first_district_cases_mean['avg_active_vs_total'] = (first_district_cases_mean['active_cases']/first_district_cases_mean['cases_total'])*100
first_district_cases_mean['avg_recovered_vs_total'] = ""
first_district_cases_mean['avg_recovered_vs_total'] = (first_district_cases_mean['recovered_total']/first_district_cases_mean['cases_total'])*100
first_district_cases_mean['avg_deaths_vs_total'] = ""
first_district_cases_mean['avg_deaths_vs_total'] = (first_district_cases_mean['deaths_total']/first_district_cases_mean['cases_total'])*100
# first_district_cases_mean

# %% [markdown]
# **Graph4 below**.
#
# DESCRIPTION:The graph below are showing **Average number of active cases per total cases** per each district

# %%
bar_graph(first_district_cases_mean.index.values,first_district_cases_mean['avg_active_vs_total'].values,"Districts","Average Number of active cases","Average number of active cases per total cases in each district")
# plt.plot(alpha_district_cases_mean.index.values,alpha_district_cases_mean["avg_active_vs_total"].values,color='red', marker='o', linestyle='-')

# %% [markdown]
# **Graph5 below**.
#
# DESCRIPTION:The graph below are showing  **Recovery rate per total cases** in each district

# %%
# bar_graph(first_district_cases_mean.index.values,first_district_cases_mean['avg_recovered_vs_total'].values,"Districts","recovery rate","Recovery rate per total cases in each district")

# %% [markdown]
# **Graph6 below**.
#
# DESCRIPTION:The graph below are showing **death rate per total cases** in each district

# %%
bar_graph(first_district_cases_mean.index.values,first_district_cases_mean['avg_deaths_vs_total'].values,"Districts","death rate","death rate per total cases in each district")

# %% [markdown]
# **Second wave & it's Potential causes :**

# %%
Second_district_cases = district_cases_dummy.get_group('second')
# Second_district_cases['month'].unique()
Second_district_cases.sort_values(by='date',ascending=False,inplace=True)
Second_district_cases = Second_district_cases.head(13).copy()
# Second_district_cases
# Out:
# <ipython-input-18-2772b569bdd8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Second_district_cases.sort_values(by='date',ascending=False,inplace=True)

# %%
# here cases_total and Deaths total are cases_today and deaths_today respectively
Second_district_cases_mean= Second_district_cases.groupby('district_name',dropna=True).mean()
Second_district_cases_mean['avg_active_vs_total'] = ""
Second_district_cases_mean['avg_active_vs_total'] = (Second_district_cases_mean['active_cases']/Second_district_cases_mean['cases_total'])*100
Second_district_cases_mean['avg_recovered_vs_total'] = ""
Second_district_cases_mean['avg_recovered_vs_total'] = (Second_district_cases_mean['recovered_total']/Second_district_cases_mean['cases_total'])*100
Second_district_cases_mean['avg_deaths_vs_total'] = ""
Second_district_cases_mean['avg_deaths_vs_total'] = (Second_district_cases_mean['deaths_total']/Second_district_cases_mean['cases_total'])*100
# Second_district_cases_mean

# %% [markdown]
# **Graph7 below**.
#
# DESCRIPTION:The graph below are showing  **Average number of active cases per total cases** in each district

# %%
bar_graph(Second_district_cases_mean.index.values,Second_district_cases_mean['avg_active_vs_total'].values,"Districts","Average Number of active cases","Average number of active cases per total cases in each district")

# %% [markdown]
# **Graph8 below**.
#
# DESCRIPTION:The graph below are showing  **Recovery rate per total cases** in each district

# %%
# bar_graph(Second_district_cases_mean.index.values,Second_district_cases_mean['avg_recovered_vs_total'].values,"Districts","recovery rate","Recovery rate per total cases in each district")

# %% [markdown]
# **Graph9 below**.
#
# DESCRIPTION:The graph below are showing  **Death rate per total cases** in each district

# %%
bar_graph(Second_district_cases_mean.index.values,Second_district_cases_mean['avg_deaths_vs_total'].values,"Districts","death rate","Death rate per total cases in each district")

# %% [markdown]
# **Third Wave and it's potential causes :**

# %%
third_district_cases = district_cases_dummy.get_group('third')
third_district_cases.sort_values(by='date',ascending=False,inplace=True)
third_district_cases = third_district_cases.head(13).copy()
# third_district_cases
# Out:
# <ipython-input-23-8dce2f0b1c18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   third_district_cases.sort_values(by='date',ascending=False,inplace=True)

# %%
# here cases_total and Deaths total are cases_today and deaths_today respectively
third_district_cases_mean= third_district_cases.groupby('district_name',dropna=True).mean()
third_district_cases_mean['avg_active_vs_total'] = ""
third_district_cases_mean['avg_active_vs_total'] = (third_district_cases_mean['active_cases']/third_district_cases_mean['cases_total'])*100
third_district_cases_mean['avg_recovered_vs_total'] = ""
third_district_cases_mean['avg_recovered_vs_total'] = (third_district_cases_mean['recovered_total']/third_district_cases_mean['cases_total'])*100
third_district_cases_mean['avg_deaths_vs_total'] = ""
third_district_cases_mean['avg_deaths_vs_total'] = (third_district_cases_mean['deaths_total']/third_district_cases_mean['cases_total'])*100
# third_district_cases_mean

# %% [markdown]
# **Graph10 below**.
#
# DESCRIPTION:The graph below are showing  **Average number of active cases per total cases** in each district

# %%
bar_graph(third_district_cases_mean.index.values,third_district_cases_mean['avg_active_vs_total'].values,"Districts","Average Number of active cases","Average number of active cases per total cases in each district")

# %% [markdown]
# **Graph11 below**.
#
# DESCRIPTION:The graph below are showing  **Recovery rate per total cases** in each district

# %%
# bar_graph(third_district_cases_mean.index.values,third_district_cases_mean['avg_recovered_vs_total'].values,"Districts","recovery rate","Recovery rate per total cases in each district")

# %% [markdown]
# **Graph12 below**.
#
# DESCRIPTION:The graph below are showing **Death rate per total cases** in each district

# %%
# bar_graph(third_district_cases_mean.index.values,third_district_cases_mean['avg_deaths_vs_total'].values,"Districts","Death rate","Death rate per total cases in each district")

# %% [markdown]
# **Comparision between all three Waves :**

# %%
overall_deaths = pd.DataFrame()
overall_deaths['district'] = ""
overall_deaths['district'] = third_district_cases_mean.index.values
overall_deaths.set_index(['district'],inplace=True)
overall_deaths['first_deaths']=""
overall_deaths['first_deaths']= first_district_cases_mean['avg_deaths_vs_total'].copy()
overall_deaths['second_deaths']=""
overall_deaths['second_deaths']= Second_district_cases_mean['avg_deaths_vs_total'].copy()
overall_deaths['third_deaths']=""
overall_deaths['third_deaths']= third_district_cases_mean['avg_deaths_vs_total'].copy()

overall_deaths['first_cases']=""
overall_deaths['first_cases']= first_district_cases_mean['cases_total'].copy()
overall_deaths['second_cases']=""
overall_deaths['second_cases']= Second_district_cases_mean['cases_total'].copy()
overall_deaths['third_cases']=""
overall_deaths['third_cases']= third_district_cases_mean['cases_total'].copy()
# overall_deaths

# %% [markdown]
# **Graph13 below**.
#
# DESCRIPTION:The graph below are showing **Death rate per total cases** in each district(All three waves)
#
# 1. Blue colour --> shows the death rate in first Wave
# 2. Yellow colour --> shows the death rate in Second Wave
# 3. Green colour --> shows the death rate in Third Wave

# %%
# plt.plot(overall_deaths.index.values,[overall_deaths["alpha_deaths"].values,overall_deaths["delta_deaths"].values,overall_deaths["omicron_deaths"].values],color='red', marker='o', linestyle='-')
# overall_deaths.plot(x=index.values,y=['alpha_deaths','delta_deaths','omicron_deaths'],kind='bar')
overall_deaths[["first_deaths","second_deaths","third_deaths"]].plot(kind="bar",title="death rate")
# Out:
# <AxesSubplot:title={'center':'death rate'}, xlabel='district'>

# %% [markdown]
# **IMPORTING VACCINATION DETAILS :**

# %%
vaccines = uk_cases[['date','month','vax_today']]
vaccines.dropna(subset=['vax_today'],inplace=True)
vaccines.sort_values(by="date",inplace=True)

# vaccines
# Out:
# <ipython-input-52-44d7e58fe90a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vaccines.dropna(subset=['vax_today'],inplace=True)
# <ipython-input-52-44d7e58fe90a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vaccines.sort_values(by="date",inplace=True)

# %% [markdown]
# **Graph14 below**.
#
# DESCRIPTION:The graph below are showing  **Vaccination rate** in Uttarakhand

# %%
# vaccinations using available data
vaccines.plot(x="date",y=['vax_today'],title="Daily Vaccination Rate")
# Out:
# <AxesSubplot:title={'center':'Daily Vaccination Rate'}, xlabel='date'>

# %% [markdown]
# # Pre-requisites:
#
# 1. The data on which analysis was done starts from June 2020 to January 2022 in most cases.
#
# # Summary of Part-1 Analysis:
#
# **PHASE-1**: **JUNE2020 to MARCH2021**
#
# 1. From **Graph1 and Graph2** we can see that from June 2020 to september 2020 active cases are increasing rapidly and from september 2020 till December 2020 was decreasing.
# 2. From **Graph3** The fatalities increased from july 2020 to october 2020 even the cases were decreasing, the possible reasons may be **Vaccinations are not done to the common people, lack of oxygen cylinders, Proper Medicines**
# 3. From **Graph4,Graph5 and Graph6** We can clearly observe that the active cases were more in haridwar and dehradun. The possibilites for more active cases in **haridwar** is because of many people were ready to celebrate **Kumbh Mela** which is to be held in **march-april2021**.and in dehradun the possible reasons are because of many people were in vactions during this phase and it was the center to travel many tourist places nearby like mussorie etc.
# 4. **NOTE**: From the data available it is not possible to accurately measure the contribution by these above written factors accurately, but the major events happened during this period does makes the domain small and more precise where we can look for causes of this aftermath after First-Wave.
#
# **PHASE-2**: **MARCH2021 to DECEMBER2021:**
#
# 1. From all the graphs and data points it is quite clear that we saw a stable environment in Uttarakhand between **January-2020 till end of March-2021**.
# 2. The Second wave started from late march 2021, again there was a hike in mass gathering for festivals like Holi and people travelling for a vaction. according to some sources like **Hindustantimes stated that despite covid nearly 9.1 million(91 lakhs) people were gathered from 1st april to 17th april to kumbh mela in haridwar** we can clearly figure out the impact in **Graph1,Graph2,Graph7,Graph8 and Graph9.**
# 3. Festivals and travelling are not the only contributers, poor vaccination rate that we can see in **Graph15** during this phase helped delta-variant to create a havoc in the city.
# 4. The Inverted cone spike in **Graph2** shows massive explosion of the virus in the cities of Uttarakhand.
# 5. The fatalities increased with the cases during Delta Variant, the possible reasons may be **Holy Festivals,Vaccinations are not done Properly, scarcity of oxygen cylinders, Proper Medicines and different fungus resulted in constant increase in deaths.**
# 6. We can see from **Graph14** that the vaccination rate has been increased drastically after second wave.
#
# **PHASE-3**: **JANUARY2022 to Now :**
#
# 1. From all the graphs and data points it is quite clear that again we saw a stable environment in Uttarkhand between **August-2020 till end of December-2021**.
# 2. There is clear spike in **Graph1** that the cases increased rapidly in january 2022 which is start of the third wave. This time there's a clear chance of same or more growth as wave 2 but the vaccinations are done to major parts of the country, so we can see the fatalites rate are not as high as second wave from the **Graph10,Graph11 and Graph12**
# 3. **Graph13** clearly shows the percentage of deaths to it's cases are almost equal to second wave

# %% [markdown]
# # PART-2: **Mucormycosis and It's potential Causes :**

# %%
muco = pd.read_csv('UK_mucormycosis_cases.csv')
# muco

# %%
muco["month"]=muco["date"].copy()
muco["month"]=muco["month"].apply(lambda x:get_month(x))
muco_districts_mean = muco.groupby('district_name').mean()
# muco_districts_mean

# %%
muco_districts_mean['avg_deaths_vs_total']= ""
muco_districts_mean['avg_deaths_vs_total']= muco_districts_mean['deaths_total']/muco_districts_mean['cases_total']
muco_districts_mean['avg_discharged_vs_total']= ""
muco_districts_mean['avg_discharged_vs_total']= muco_districts_mean['discharged_total']/muco_districts_mean['cases_total']

# %% [markdown]
# **Graph14 below**.
#
# DESCRIPTION:The graph below are showing  **death rate due to Mucormycosis** in each district

# %%
bar_graph(muco_districts_mean.index.values,muco_districts_mean['avg_deaths_vs_total'].values,"Districts","death rate","death rate per district due to Mucormycosis")

# %% [markdown]
# **Graph15 below**.
#
# DESCRIPTION:The graph below are showing  **Mucormycosis recovery rate ** in each district

# %%
bar_graph(muco_districts_mean.index.values,muco_districts_mean['avg_discharged_vs_total'].values,"Districts","death rate","discharged per active cases in districts due to Mucormycosis")

# %%
muco_hosp_mean = muco.groupby('hospital_name').mean()
muco_hosp_mean.drop(['City Heart','HIHT JolyGrant','Krishna Hospital Research Haldwani','Max'],inplace=True)
muco_hosp_mean['avg_deaths_vs_total']= ""
muco_hosp_mean['avg_deaths_vs_total']= muco_hosp_mean['deaths_total']/muco_hosp_mean['cases_total']
muco_hosp_mean['avg_discharged_vs_total']= ""
muco_hosp_mean['avg_discharged_vs_total']= muco_hosp_mean['discharged_total']/muco_hosp_mean['cases_total']
muco_hosp_mean.drop(muco_hosp_mean[(muco_hosp_mean['deaths_total'] == 0.000000) & (muco_hosp_mean['discharged_total'] == 0.000000)].index,inplace=True)
# muco_hosp_mean

# %% [markdown]
# **Graph16 below**.
#
# DESCRIPTION:The graph below are showing  **death rate due to Mucormycosis** in each Hospital

# %%
bar_graph(muco_hosp_mean.index.values,muco_hosp_mean['avg_deaths_vs_total'].values,"Districts","death rate","death rate in each hospital due to Mucormycosis")

# %% [markdown]
# **Graph17 below**.
#
# DESCRIPTION:The graph below are showing  **Mucormycosis recovery rate ** in each Hospital

# %%
bar_graph(muco_hosp_mean.index.values,muco_hosp_mean['avg_discharged_vs_total'].values,"Districts","death rate","discharged per active cases in districts due to Mucormycosis")

# %% [markdown]
# # Pre-requisites:
#
# 1. The data on which analysis was done starts from June 2020 to January 2022 in most cases.
#
# # Summary of Part-2 Analysis:
#
# 1. From **Graph14** we can see that the **haridwar was the most effected district due to mucormycosis** excluding udham singh nagar as only one case is reported and deceased in that district followed by Dehradun.From **Graph16** These two districts reported most because only hospitals from these districts took charge of most of mucormycosis cases of other states.
# 2. **Sri Mahant Indresh Hospital** has been sucessfully discharged most of it's patients from the above **Graph17**.
