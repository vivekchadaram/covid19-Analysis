# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# plt.figure(figsize=(30,12))
plt.rcParams['figure.figsize'] = [30,12]
import plotly.io as pio

# %%
def get_month(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[2]
    if date[1]=="02":
        return "February"+date[2]
    if date[1]=="03":
        return "March"+date[2]
    if date[1]=="04":
        return "April"+date[2]
    if date[1]=="05":
        return "May"+date[2]
    if date[1]=="06":
        return "June"+date[2]
    if date[1]=="07":
        return "July"+date[2]
    if date[1]=="08":
        return "August"+date[2]
    if date[1]=="09":
        return "September"+date[2]
    if date[1]=="10":
        return "October"+date[2]
    if date[1]=="11":
        return "November"+date[2]
    if date[1]=="12":
        return "December"+date[2]
    
    
def get_year(date):
    date=date.split("-")
    return date[2]
def Histogram(x,y,xlabel,ylabel,title):
    x.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["red"],rwidth=0.8
       )
    y.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["blue"],rwidth=0.8
       )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def bar_graph(categories,cat_val,xlabel,ylabel,title=""):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.bar(categories,cat_val,width=0.8)
    plt.title(title)
    plt.show()
    
# This is the code of linear_regression model also.........           
def linear_correlation(x,y):
    meanx=sum(x.values)/len(x)
    meany=sum(y.values)/len(y)
    if len(x.values)==len(y.values):
        num,den=0,0
        #numerator calculation
        a=0
        for i in range(len(x)):
            a+=x.values[i]*y.values[i]
            #         print(a)
        num=a*len(x)-(sum(x.values)*sum(y.values))
    
        #denominator calculation
        ax,ay=0,0
        for i in range(len(x)):
                ax+=x.values[i]**2
                ay+=y.values[i]**2 
        p1=(len(x)*ax-(sum(x.values)**2))**0.5
        p2=(len(y)*ay-(sum(y.values)**2))**0.5
        den=p1*p2
        #print(num,den)
        return num/den
    else:
        raise Exception("Invalid Dimension")
import datetime
import calendar
 
def get_day(date):
    day, month, year = (int(i) for i in date.split('-'))   
    dayNumber = calendar.weekday(year, month, day)
    days =["Monday", "Tuesday", "Wednesday", "Thursday",
                         "Friday", "Saturday", "Sunday"]
    return (days[dayNumber])

def set_index(x):
    if x=="June2020":
        return -2
    if x=="July2020":
        return -1
    if x=="August2020":
        return 0
    if x=="September2020":
        return 1
    if x=="October2020":
        return 2
    if x=="November2020":
        return 3
    if x=="December2020":
        return 4
    if x=="January2021":
        return 5
    if x=="February2021":
        return 6
    if x=="March2021":
        return 7
    if x=="April2021":
        return 8
    if x=="May2021":
        return 9
    if x=="June2021":
        return 10
    if x=="July2021":
        return 11
    if x=="August2021":
        return 12
    if x=="September2021":
        return 13
    if x=="October2021":
        return 14
    if x=="November2021":
        return 15
    if x=="December2021":
        return 16
    if x=="January2022":
        return 17
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    #     explode = (0,0.1)
    plt.pie(values,labels=values,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1
# vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
def plot_bar_graphs(data,values,xlabel="",ylabel="",title=""):
    data[values].plot(kind="bar",title="",xlabel=xlabel,ylabel=ylabel)
    
def get_date_month_year(case_info):
    case_info["day"]=case_info["date"].copy()
    case_info["month"]=case_info["date"].copy()
    case_info["year"]=case_info["date"].copy()
    case_info["day"]=case_info["day"].apply(lambda x:get_day(x))
    case_info["month"]=case_info["month"].apply(lambda x:get_month(x))
    case_info["year"]=case_info["year"].apply(lambda x:get_year(x))
    return case_info
def order_by_date(date):
    date=date.split("-")
    s=""
    for i in range(len(date)-1,-1,-1):
        s=s+date[i]

    return int(s)

# %%
case_info=pd.read_csv("GA_active_cases.csv")
case_info
# Out:
#              date district                           location  cases
# 0      2021-12-11    NORTH   COMMUNITY HEALTH CENTRE BICHOLIM      8
# 1      2021-12-11    NORTH   COMMUNITY HEALTH CENTRE SANKHALI     10
# 2      2021-12-11    NORTH     COMMUNITY HEALTH CENTRE PERNEM      9
# 3      2021-12-11    NORTH     COMMUNITY HEALTH CENTRE VALPOI      2
# 4      2021-12-11    NORTH         URBAN HEALTH CENTRE MAPUSA     18
# ...           ...      ...                                ...    ...
# 14513  2022-01-03    SOUTH      PRIMARY HEALTH CENTRE SANGUEM     15
# 14514  2022-01-03    SOUTH      PRIMARY HEALTH CENTRE SHIRODA      9
# 14515  2022-01-03    SOUTH  PRIMARY HEALTH CENTRE DHARBANDORA      8
# 14516  2022-01-03    SOUTH        PRIMARY HEALTH CENTRE PONDA     82
# 14517  2022-01-03    SOUTH      PRIMARY HEALTH CENTRE NAVELIM     44
#
# [14518 rows x 4 columns]

# %%
case_info["date"]=case_info["date"].apply(lambda x: rearrange_date(x))
case_info
# Out:
#              date district                           location  cases
# 0      11-12-2021    NORTH   COMMUNITY HEALTH CENTRE BICHOLIM      8
# 1      11-12-2021    NORTH   COMMUNITY HEALTH CENTRE SANKHALI     10
# 2      11-12-2021    NORTH     COMMUNITY HEALTH CENTRE PERNEM      9
# 3      11-12-2021    NORTH     COMMUNITY HEALTH CENTRE VALPOI      2
# 4      11-12-2021    NORTH         URBAN HEALTH CENTRE MAPUSA     18
# ...           ...      ...                                ...    ...
# 14513  03-01-2022    SOUTH      PRIMARY HEALTH CENTRE SANGUEM     15
# 14514  03-01-2022    SOUTH      PRIMARY HEALTH CENTRE SHIRODA      9
# 14515  03-01-2022    SOUTH  PRIMARY HEALTH CENTRE DHARBANDORA      8
# 14516  03-01-2022    SOUTH        PRIMARY HEALTH CENTRE PONDA     82
# 14517  03-01-2022    SOUTH      PRIMARY HEALTH CENTRE NAVELIM     44
#
# [14518 rows x 4 columns]

# %%
print(len(case_info["district"].unique()))
# Out:
# 3

# %%
case_info["day"]=case_info["date"].copy()
case_info["month"]=case_info["date"].copy()
case_info["year"]=case_info["date"].copy()
case_info["day"]=case_info["day"].apply(lambda x:get_day(x))
case_info["month"]=case_info["month"].apply(lambda x:get_month(x))
case_info["year"]=case_info["year"].apply(lambda x:get_year(x))
case_info
# Out:
#              date district                           location  cases  \
# 0      11-12-2021    NORTH   COMMUNITY HEALTH CENTRE BICHOLIM      8
# 1      11-12-2021    NORTH   COMMUNITY HEALTH CENTRE SANKHALI     10
# 2      11-12-2021    NORTH     COMMUNITY HEALTH CENTRE PERNEM      9
# 3      11-12-2021    NORTH     COMMUNITY HEALTH CENTRE VALPOI      2
# 4      11-12-2021    NORTH         URBAN HEALTH CENTRE MAPUSA     18
# ...           ...      ...                                ...    ...
# 14513  03-01-2022    SOUTH      PRIMARY HEALTH CENTRE SANGUEM     15
# 14514  03-01-2022    SOUTH      PRIMARY HEALTH CENTRE SHIRODA      9
# 14515  03-01-2022    SOUTH  PRIMARY HEALTH CENTRE DHARBANDORA      8
# 14516  03-01-2022    SOUTH        PRIMARY HEALTH CENTRE PONDA     82
# 14517  03-01-2022    SOUTH      PRIMARY HEALTH CENTRE NAVELIM     44
#
#             day         month  year
# 0      Saturday  December2021  2021
# 1      Saturday  December2021  2021
# ...

# %%
loc_mean=case_info.groupby(["location"]).mean()
loc_sum=case_info.groupby(["location"]).sum()

dis_sum=case_info.groupby(["district"]).sum()
dis_mean=case_info.groupby(["district"]).mean()

date_mean=case_info.groupby(["date"]).mean()
date_mean["date"]=date_mean.index.values
date_mean["day"]=date_mean["date"].copy()
date_mean["month"]=date_mean["date"].copy()
date_mean["year"]=date_mean["date"].copy()
date_mean["day"]=date_mean["day"].apply(lambda x:get_day(x))
date_mean["month"]=date_mean["month"].apply(lambda x:get_month(x))
date_mean["year"]=date_mean["year"].apply(lambda x:get_year(x))
date_mean["Index"]=date_mean["month"].values.copy()
date_mean["Index"]=date_mean["Index"].apply(lambda x:set_index(x))
date_mean.sort_values(["Index"],inplace=True)
date_mean.dropna(inplace=True)

date_sum=case_info.groupby(["date"]).sum()
# loc_mean


# dis_sum
date_sum["date"]=date_sum.index.values
date_sum["day"]=date_sum["date"].copy()
date_sum["month"]=date_sum["date"].copy()
date_sum["year"]=date_sum["date"].copy()
date_sum["day"]=date_sum["day"].apply(lambda x:get_day(x))
date_sum["month"]=date_sum["month"].apply(lambda x:get_month(x))
date_sum["year"]=date_sum["year"].apply(lambda x:get_year(x))
date_sum["Index"]=date_sum["month"].values.copy()
date_sum["Index"]=date_sum["Index"].apply(lambda x:set_index(x))
date_sum.sort_values(["Index"],inplace=True)
date_sum.dropna(inplace=True)
# date_sum

# %%
month_mean=case_info.groupby(["month"]).mean()
month_mean["Index"]=month_mean.index.values.copy()
month_mean["Index"]=month_mean["Index"].apply(lambda x:set_index(x))
month_mean.sort_values(["Index"],inplace=True)
month_mean.dropna(inplace=True)

# %% [markdown]
# # PART-1: SECOND WAVE AND ITS IMPACT AND CAUSES.

# %% [markdown]
# **Graph1 below**
#
# DESCRIPTION:The graph below shows *Trend of new cases every day.*

# %%
date_sum.plot(x="date",y=["cases"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **Graph2 below**
#
# DESCRIPTION:The graph below shows *Trend of average new cases per month.*

# %%
plt.plot(month_mean.index.values,month_mean["cases"].values,color='red', marker='o', linestyle='-')

# %% [markdown]
# IMPORTING OVERVIEW DATA

# %%
comp_data=pd.read_csv("GA_overview.csv")

# %%
comp_data
# Out:
#            date  recovery_rate  recovered_patients  recovery_in_last_24_hrs  \
# 0    2021-12-13          97.85              175605                     44.0
# 1    2021-12-12          97.83              175561                     60.0
# 2    2021-12-11          97.82              175501                     58.0
# 3    2021-12-10          97.81              175443                     35.0
# 4    2021-12-08          97.86              175478                     28.0
# ..          ...            ...                 ...                      ...
# 428  2022-10-04          85.01               30033                    506.0
# 429  2022-10-03          84.60               29527                    523.0
# 430  2021-12-31          97.47              176304                     21.0
# 431  2022-01-01          97.32              176322                     18.0
# 432  2022-01-03          96.84              176438                     62.0
#
#      home_isolation_cumulative  home_isolation_new  \
# ...

# %%
comp_data["date"]=comp_data["date"].apply(lambda x: rearrange_date(x))
comp_data=get_date_month_year(comp_data)
comp_data["Index"]=comp_data.month.values.copy()
comp_data["Index"]=comp_data["Index"].apply(lambda x:set_index(x))
comp_data.sort_values(["Index"],inplace=True)
comp_data.dropna(subset=["Index"],inplace=True)
comp_data

# comp_data=comp_data[(comp_data["month"]!="July2022")|(comp_data["month"]!="October2022")]
comp_data_mean=comp_data.groupby(["month"]).mean()
comp_data_mean["Index"]=comp_data_mean.index.values.copy()
comp_data_mean["Index"]=comp_data_mean["Index"].apply(lambda x:set_index(x))
comp_data_mean["date"]=comp_data_mean.index.values
comp_data_mean.sort_values(["Index"],inplace=True)


comp_data_sum=comp_data.groupby(["month"]).sum()
comp_data_sum["Index"]=comp_data_sum.index.values.copy()
comp_data_sum["Index"]=comp_data_sum["Index"].apply(lambda x:set_index(x))
comp_data_sum.sort_values(["Index"],inplace=True)
# comp_data_sum

# %%
def remove_irregularities(x,y):
    x1=comp_data_mean[x].values
    y1=comp_data_sum[y].values

    # removing incorrct data from comp_data_mean
#     print(len(x1),len(y1))
    for i in range(1,len(x1)-1):
        if x1[i-1]>x1[i]:
            x1[i]=y1[i]+x1[i-1]

    comp_data_mean[x]=x1.copy()
    comp_data_mean

# %%
# Removing irregularities from cumulative data......
mean=['home_isolation_cumulative','hospitalized_patients_cumulative','samples_tested_cumulative','total_cases_cunulative','deaths_cumulative']
s=['home_isolation_new','hospitalized_patients_new','samples_tested_new','total_cases_new','deaths_new']
for i in range(len(mean)):
    remove_irregularities(mean[i],s[i])
comp_data_mean
# Out:
#                recovery_rate  recovered_patients  recovery_in_last_24_hrs  \
# month
# September2020      80.297500        23838.375000               529.812500
# October2020        89.207407        35583.444444               397.740741
# November2020       95.047241        43749.896552               175.137931
# December2020       96.330645        47835.483871               111.225806
# January2021        96.953226        50709.741935                80.741935
# February2021       97.411071        52858.000000                60.500000
# March2021          96.926452        54526.032258                66.709677
# April2021          87.921333        59378.000000               376.200000
# May2021            76.598889        95221.722222              2373.722222
# June2021           95.974000       157654.266667               465.666667
# July2021           97.232593       164717.370370               176.518519
# August2021         97.614286       168506.892857                94.607143
# ...

# %% [markdown]
# **Graph3 and Graph4 below**
# DESCRIPTION:
# 1. **Graph3** is showing *Trend of Total new cases everyday*.
# 1. **Graph4** is showing *Trend of Average new cases per month*.

# %%
comp_data.plot(x="date",y=["total_cases_new"])
comp_data_mean.plot(x="date",y=["total_cases_new"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **Graph5 and Graph6 below**
# DESCRIPTION:
# 1. **Graph5** is showing *Trend of active cases everyday*.
# 1. **Graph6** is showing *Trend of Average active cases per month*.

# %%
comp_data.plot(x="date",y=["active_cases"])
comp_data_mean.plot(x="date",y=["active_cases"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **Graph7 and Graph8 below**
#
# DESCRIPTION:The graphs below are showing
# 1. **Graph7** is showing *Trend of recovery rate on daily basis.*
# 2. **Graph8** is showing *Trend of Average recovery rate per month.*

# %%
comp_data.plot(x="date",y=["recovery_rate"])
comp_data_mean.plot(x="date",y=["recovery_rate"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# DEATHS AND FATALITY RATE

# %% [markdown]
# **Graph9 and Graph10 below**
#
# DESCRIPTION:The graphs below are showing
# 1. **Graph9** is showing *Trend of recovery rate on daily basis.*
# 2. **Graph10** is showing *Trend of Average recovery rate per month.*

# %%
comp_data.plot(x="date",y=["deaths_new"])
comp_data_mean.plot(x="date",y=["deaths_new"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **Graph11 below**
#
# DESCRIPTION: The graph is showing *Trend of Cumulative deaths.*
#
# **PROPERTIES OF THE GRAPH:**
#
# 1. If the graph is going up -> means that average case is increasing.
# 2. If the graph is flat -> which means that average case is neither increaing nor decreasing.
# 3. The graph cant go down as the graph is drawn on cumulative data.

# %%
comp_data_mean.plot(x="date",y=["deaths_cumulative"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# HOSPITALISATION

# %% [markdown]
# **Graph12 and Graph13 below**
#
# DESCRIPTION:The graphs below are showing
# 1. **Graph12** is showing *Trend of number of patients hopitalised on daily basis.*
# 2. **Graph13** is showing *Trend of Average of number of patients hopitalised per-month.*

# %%
comp_data.plot(x="date",y=["hospitalized_patients_new"])
comp_data_mean.plot(x="date",y=["hospitalized_patients_new"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **Graph14 below**
#
# DESCRIPTION: The graph is showing *Trend of Hospitalised patients cumulative per month analysis.*
#
# **PROPERTIES OF THE GRAPH:**
#
# 1. If the graph is going up -> means that average case is increasing.
# 2. If the graph is flat -> which means that average case is neither increasing nor decreasing.
# 3. The graph cant go down as the graph is drawn on cumulative data.

# %%
comp_data_mean.plot(x="date",y=["hospitalized_patients_cumulative"])
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # PRE-REQUISITES:
# 1. The above analysis was carried out on data points from **September2020 to January2022.**
#
# # SUMMARY OF PART-1:
# 1. It can be seen that there was a gradual decrease in number of active cases,new cases, hopitalisation and fatility from **september 2020 to March 2021** from graphs (**Graph3, Graph4,Graph10,Graph12, Graph13**).
# 2. The recovery rate is also seems fairly higher in the period **September-2020 to March-2021.**
# 3. Just like all other states, similarly in goa second wave was from mid **march-2021 to end of June-2021.**
# 4. There was very little surge and small spike (from **Graph12 and Graph13 and Graph5**) in cases and hospitalisation from **mid-November-2021 to "early December 2021"** due to heavy off season raining along west coast, (**Source:** https://timesofindia.indiatimes.com/city/goa/rain-sweeps-across-state-from-ktaka/articleshow/87824301.cms).
# 5. The fall in number of hospitalisation from **September-2020** shows from **Graph13 and Graph14**  that hospitalisation ratio was equal in Goa for both the **First and Second Wave, even though there was a much bigger difference in number of new cases during those two different waves.**

# %% [markdown]
# # PART-2: DISTRICT WISE ANALYSIS

# %% [markdown]
# DIVIDING THE DATASETS INTO TWO PARTS

# %%
south=comp_data[case_info["district"]=="SOUTH"]
north=comp_data[case_info["district"]=="NORTH"]
# south
# Out:
# C:\Users\anura\AppData\Local\Temp/ipykernel_7556/3493013337.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   south=comp_data[case_info["district"]=="SOUTH"]
# C:\Users\anura\AppData\Local\Temp/ipykernel_7556/3493013337.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   north=comp_data[case_info["district"]=="NORTH"]

# %%
# north

# %% [markdown]
# **SOUTH DISTRICT V/S NORTH DISTRICT**

# %%
south_mean=south.groupby(["month"]).sum()
south_mean["Index"]=south_mean.index.values.copy()
south_mean["Index"]=south_mean["Index"].apply(lambda x:set_index(x))
south_mean.sort_values(["Index"],inplace=True)
south_mean.dropna(inplace=True)


north_mean=north.groupby(["month"]).sum()
north_mean["Index"]=north_mean.index.values.copy()
north_mean["Index"]=north_mean["Index"].apply(lambda x:set_index(x))
north_mean.sort_values(["Index"],inplace=True)
north_mean.dropna(inplace=True)

south_sum=south.groupby(["month"]).sum()
south_sum["Index"]=south_sum.index.values.copy()
south_sum["Index"]=south_sum["Index"].apply(lambda x:set_index(x))
south_sum.sort_values(["Index"],inplace=True)
south_sum.dropna(inplace=True)

north_sum=north.groupby(["month"]).sum()
north_sum["Index"]=north_sum.index.values.copy()
north_sum["Index"]=north_sum["Index"].apply(lambda x:set_index(x))
north_sum.sort_values(["Index"],inplace=True)
north_sum.dropna(inplace=True)


dis_merge_mean=pd.merge(south_mean,north_mean,left_index=True,right_index=True)
dis_merge_sum=pd.merge(south_sum,north_sum,left_index=True,right_index=True)
# dis_merge_mean
# north_mean
# south_mean
# north_sum

# %% [markdown]
# **NEW CASES**

# %% [markdown]
# **Graph15 and Graph16 below**
#
# DESCRIPTION:
#
# **Graph15:** The first graph is showing *Average new cases in south district V/S Average new cases in north district*
#
# **Graph16:** The second graph is showing *total new cases in south district V/S total new cases in north district*
#
# **NOTE:** In both the graphs
# 1. **South district** is shown in **Blue Color.**
# 2. **North district** is shown in **Orange Color.**

# %%
dis_merge_mean[["total_cases_new_x","total_cases_new_y"]].plot(kind="bar")
dis_merge_sum[["total_cases_new_x","total_cases_new_y"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# **TESTING**

# %% [markdown]
# **Graph17 and Graph18 below**
#
# DESCRIPTION:
#
# **Graph17:** The first graph is showing *Average new sample tested in south district V/S Average new sample tested in north district*
#
# **Graph18:** The second graph is showing *total new sample tested in south district V/S total new sample tested in north district*
#
# **NOTE:** In both the graphs
# 1. **South district** is shown in **Blue Color.**
# 2. **North district** is shown in **Orange Color.**

# %%
dis_merge_mean[['samples_tested_new_x','samples_tested_new_y']].plot(kind="bar")
dis_merge_sum[['samples_tested_new_x','samples_tested_new_y']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# **Graph19 and Graph20 below**
#
# DESCRIPTION:
#
# **Graph19:** The first graph is showing *Average of test per million sample tested in south district V/S Average of test per million tested in north district*
#
# **Graph20:** The second graph is showing *total test per million tested in south district V/S total new sample tested in north district*
#
# **NOTE:** In both the graphs
# 1. **South district** is shown in **Blue Color.**
# 2. **North district** is shown in **Orange Color.**

# %%
dis_merge_mean[['tests_per_million_x','tests_per_million_y']].plot(kind="bar")
dis_merge_sum[['tests_per_million_x','tests_per_million_y']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# **HOSPITALISATION**

# %% [markdown]
# **Graph21 and Graph22 below**
#
# DESCRIPTION:
#
# **Graph21:** The first graph is showing *Average of new hospitalized patients in south district V/S Average of new hospitalized patients in north district*
#
# **Graph22:** The second graph is showing *total number of new hospitalized patients in south district V/S total number of new hospitalized patients in north district*
#
# **NOTE:** In both the graphs
# 1. **South district** is shown in **Blue Color.**
# 2. **North district** is shown in **Orange Color.**

# %%
dis_merge_mean[["hospitalized_patients_new_x",'hospitalized_patients_new_y']].plot(kind="bar")
dis_merge_sum[['hospitalized_patients_new_x','hospitalized_patients_new_y']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# **DEATH AND FATALITY**

# %% [markdown]
# **Graph23 and Graph24 below**
#
# DESCRIPTION:
#
# **Graph23:** The first graph is showing *Average of new deaths in south district V/S Average of new deaths in north district*
#
# **Graph24:** The second graph is showing *total number of new deaths in south district V/S total number of new deaths in north district*
#
# **NOTE:** In both the graphs
# 1. **South district** is shown in **Blue Color.**
# 2. **North district** is shown in **Orange Color.**

# %%
dis_merge_mean[['deaths_new_x','deaths_new_y']].plot(kind="bar")
dis_merge_sum[['deaths_new_x','deaths_new_y']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# # SUMMARY OF PART-2 ANALYSIS:

# %% [markdown]
# # PRE-REQUISITES:
#
# 1. The above analysis was conducted on data points between **September-2020 to December-2021**
#
# # SUMMARY PART-2:
#
# 1. It was noted from graphs (**Graph15 and Graph16**) that during start of Second wave on april-2021 most positve cases were from South district and on May-2021 the number of positve cases from North district suddenly and there was significantly less cases from South district. This could be due to stricter lockdowns and curfew protocols followed by Southern part duitng April-2021 which might have resulted in better results in May-2021 by southern districts which Northern district failed to do so. One more reason which cant be ignored is that during May-2021 the number of sample testing conducted by Southern distrits were significantly lower than **April-2021** which could be a potential reason for such drastic change in number of positive cases in the southern parts.
# 2. The same trend is aslo seen in fatility rate and hospitalisation.

# %% [markdown]
# # PART-3: PREDICTOR MODEL

# %%
pred_data=pd.read_csv("rough.csv")
pred_data.drop(["Unnamed: 0"],axis="columns",inplace=True)
pred_data
# Out:
#      level_0        date  recovery_rate  recovered_patients  \
# 0          0  15-09-2020          78.76               20094
# 1          1  16-09-2020          78.21               20445
# 2          2  17-09-2020          77.82               20844
# 3          3  18-09-2020          77.84               21314
# 4          4  19-09-2020          77.65               21760
# ..       ...         ...            ...                 ...
# 425      425  29-12-2021          97.68              176222
# 426      426  30-12-2021          97.58              176283
# 427      427  31-12-2021          97.47              176304
# 428      428  01-01-2022          97.32              176322
# 429      429  03-01-2022          96.84              176438
#
#      recovery_in_last_24_hrs  home_isolation_cumulative  home_isolation_new  \
# 0                      446.0                      10297                 434
# 1                      351.0                      10573                 276
# ...

# %% [markdown]
# ### RELATION AND ASSOCIATION

# %%
print(linear_correlation(pred_data["recovered_patients"],pred_data["hospitalized_patients_cumulative"]))
print(linear_correlation(pred_data["total_cases_cumulative"],pred_data["hospitalized_patients_cumulative"]))
print(linear_correlation(pred_data["level_0"],pred_data["hospitalized_patients_cumulative"]))
print(linear_correlation(pred_data["samples_tested_cumulative"],pred_data["hospitalized_patients_cumulative"]))
# Out:
# 0.9874456213207226
# 0.9906555713232578
# 0.9415380398462173
# 0.9525148570054999

# %% [markdown]
# To accurately predict the total hospitalized patients some of the best attributes that can be identified from above values are:
#
#    1. recovered_patients.
#    2. Number of Days starting from last date in the dataset.
#    3. cumulative cases.
#    4. cumulative samples tested.

# %%
# TAKING x and y values....

# NOTE: This analysis is done on total cumulative cases in Goa
x=np.array(pred_data["level_0"]).reshape(-1,1)
y=np.array(pred_data["total_cases_cumulative"]).reshape(-1,1)



# now, we need to clean the values of x and y in our desired format......

cases_new=pred_data["total_cases_new"].values
for i in range (1,len(y)):
    if y[i-1]>y[i]:
        y[i]=y[i-1]+cases_new[i]
        
# ========= CLEANING COMPLETED===========================

# PLOTTING THE GRAPH
plt.plot(x,y,"-r")


# getting slope and intercept value of our graph
slope, intercept = np.polyfit( pred_data["level_0"],y,1)


# The graph below is showing trend of cumulative cases starting from 15-09-2020 to 3-01-2022

# %%
# MODEL-1: USING intercept and slope to find the best fit curve.....

def calculate_predicted_val(slope,intercept):
    err=list(list())
    m=slope[0]
    c=intercept[0]
    lis=[]
    
    # predicting    
    
    for i in range(1,50):
        y=m*(i+430)+c
        lis.append([i+430,round(y,2)])
    
    return lis

lis=calculate_predicted_val(slope,intercept) 
# lis

# %%
# MODEL-2: CODE TO PREDICT FUTURE VALUES USING PolynomialFeatures........
# NOTE: Incase-> If MODEL-2 is not working please run the same in an IDLE
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
# Best value of degree is found by hit and trial method....
polyfeat = PolynomialFeatures(degree=5)
x = polyfeat.fit_transform(x)
# x
model = linear_model.LinearRegression()
model.fit(x, y)
accuracy = model.score(x, y)
print("Accuracy of Model-2 is {}%".format(round(accuracy*100,2)))
# Out:
# Accuracy of Model-2 is 96.35%

# %%
# FINDING PREDICTION FOR NEXT 50 days after 3rd January-2022 USING MODEL-2
plis=[]
dict1={1:[]}
for i in range(1,50):
    y=model.predict(polyfeat.fit_transform([[430 + i]]))
    dict1[1].append(y[0][0])
    plis.append([430 + i,y[0][0]])


df=pd.DataFrame(dict1)

df.to_csv("future.csv")
# print(plis)
# print(df.head())

# %%
# After reading different predicted values from MODEL1 and MODEL2 repsectively.........
# We will use average of the two sets of value to predict the values to reach as close as possible to real values.....
final_lis=[]
for i in range(len(plis)):
    final_lis.append([plis[i][0],round((plis[i][1]+lis[i][1])/2,2)])
# print(final_lis)

x_axis=[]
y_axis=[]
for i in range(len(final_lis)):
    x_axis.append(final_lis[i][0]-430)
    y_axis.append(final_lis[i][1])
    
rate=[]
for i in range(1,len(final_lis)):
    rate.append(round(abs(final_lis[i-1][1]-final_lis[i][1]),2))
# print(rate)
print("Average rate at which cases is predicted to increase in Goa is : {} cases per day".format(round(sum(rate)/len(rate),2)))
# Out:
# Average rate at which cases is predicted to increase in Goa is : 1722.37 cases per day

# %% [markdown]
# **Graph25 below**
#
# DESCRIPTION: Showing trend of Cumulative cases for next 50 days starting from 3rd January 2022

# %%
# PLOTTING THE GRAPH
plt.plot(x_axis,y_axis,"-r")

# %% [markdown]
# **Graph26 below**
#
# DESCRIPTION: Showing trend of Cumulative cases for next 50 days starting from 3rd January 2022

# %%
bar_graph(x_axis,y_axis,"Number of Days","Number of Positive cases (Cumulative)","Predicted Values for next 50 days, starting from 4th January")

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # VERIFICATION OF THE PREDICTED VALUES WITH ACTUAL VALUES UPDATED BY GOA GOVT.
#
# **Source:** https://www.goa.gov.in/covid-19/
#
# # ACTUAL VALUES OF CUMULATIVE CASES ON
#
# **19th JAN 2022=219107** , **20th JAN 2022=222497** , **21st JAN 2022=225165** , **22nd JAN 2022=227856** , **23rd JAN 2022=229438** , **24th JAN 2022=230825**
#
#
# # PREDICTED VALUES USING AVERAGE OF MODEL-1 and MODEL-2 FOR SAME DAYS ARE:
#
#
# **19th JAN 2022=215043** , **20th JAN 2022=216343** , **21st JAN 2022=217680** , **22nd JAN 2022=219056** , **23rd JAN 2022=220471** , **24th JAN 2022=221925**
#
# # PREDICTED VALUES USING MODEL-2 FOR SAME DAYS ARE:
#
#
# **19th JAN 2022=215495** , **20th JAN 2022=217637** , **21st JAN 2022=219853** , **22nd JAN 2022=222147** , **23rd JAN 2022=224518** , **24th JAN 2022=226969**

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # PRE-REQUISITES:
#
# 1. The models were developed on cumulative data to understand the nature of trend of cases after 3rd january that is trend of cases during Third wave.
# 2. The analysis values may go wrong and is not applicable on every-day purpose or for long-term scenario as the model is developed on very limited data.It should be used to get an overall idea and only for educational purpose.
#
# # SUMMARY OF PART-3 ANALYSIS:
#
# 1. From the above details, it is quite clear the model was able to depict the trend of cases during third wave even though the values are not very accurate but it does shows us how is the virus is going to spread and to learn about its behaviour for short-term.
# 2. You can also refer **future.csv** file to get the values of first 50 days after 3rd january 2021.

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------
